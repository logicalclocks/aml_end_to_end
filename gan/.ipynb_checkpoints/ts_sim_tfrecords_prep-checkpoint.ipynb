// %%
val sc = spark.sparkContext
// Out:
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>2565</td><td>application_1560190780506_0022</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://lx69384.sbcore.net:8088/proxy/application_1560190780506_0022/">Link</a></td><td><a target="_blank" href="http://lx69387.sbcore.net:8042/node/containerlogs/container_e12_1560190780506_0022_01_000001/aml_dev__davitbzh">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// sc: org.apache.spark.SparkContext = org.apache.spark.SparkContext@5265600

// %%
import org.apache.spark.sql.types.{FloatType,LongType}
import org.apache.spark.sql.types.{ArrayType, StructField, StructType}
import org.apache.spark.sql.functions.explode
import org.apache.spark.sql.expressions.Window
// Out:
// import org.apache.spark.sql.types.{FloatType, LongType}
// import org.apache.spark.sql.types.{ArrayType, StructField, StructType}
// import org.apache.spark.sql.functions.explode
// import org.apache.spark.sql.expressions.Window

// %%
val df_all = spark.read.parquet("hdfs:///Projects/aml_dev/aml_dev_Training_Datasets/ts_sim_ano.parquet")
// Out:
// df_all: org.apache.spark.sql.DataFrame = [_1: double, _2: double ... 364 more fields]

// %%
df_all.count()
// Out:
// res4: Long = 510000

// %%
df_all.where($"target" === 1).count()
// Out:
// res5: Long = 10000

// %%
df_all.where($"target" === 0).count()
// Out:
// res6: Long = 500000

// %%
df_all.printSchema
// Out:
// root
//  |-- _1: double (nullable = true)
//  |-- _2: double (nullable = true)
//  |-- _3: double (nullable = true)
//  |-- _4: double (nullable = true)
//  |-- _5: double (nullable = true)
//  |-- _6: double (nullable = true)
//  |-- _7: double (nullable = true)
//  |-- _8: double (nullable = true)
//  |-- _9: double (nullable = true)
//  |-- _10: double (nullable = true)
//  |-- _11: double (nullable = true)
//  |-- _12: double (nullable = true)
//  |-- _13: double (nullable = true)
//  |-- _14: double (nullable = true)
//  |-- _15: double (nullable = true)
//  |-- _16: double (nullable = true)
//  |-- _17: double (nullable = true)
//  |-- _18: double (nullable = true)
//  |-- _19: double (nullable = true)
//  |-- _20: double (nullable = true)
//  |-- _21: double (nullable = true)
//  |-- _22: double (nullable = true)
//  |-- _23: double (nullable = true)
//  |-- _24: double (nullable = true)
//  |-- _25: double (nullable = true)
//  |-- _26: double (nullable = true)
//  |-- _27: double (nullable = true)
//  |-- _28: double (nullable = true)
//  |-- _29: double (nullable = true)
//  |-- _30: double (nullable = true)
//  |-- _31: double (nullable = true)
//  |-- _32: double (nullable = true)
//  |-- _33: double (nullable = true)
//  |-- _34: double (nullable = true)
//  |-- _35: double (nullable = true)
//  |-- _36: double (nullable = true)
//  |-- _37: double (nullable = true)
//  |-- _38: double (nullable = true)
//  |-- _39: double (nullable = true)
//  |-- _40: double (nullable = true)
//  |-- _41: double (nullable = true)
//  |-- _42: double (nullable = true)
//  |-- _43: double (nullable = true)
//  |-- _44: double (nullable = true)
//  |-- _45: double (nullable = true)
//  |-- _46: double (nullable = true)
//  |-- _47: double (nullable = true)
//  |-- _48: double (nullable = true)
//  |-- _49: double (nullable = true)
//  |-- _50: double (nullable = true)
//  |-- _51: double (nullable = true)
//  |-- _52: double (nullable = true)
//  |-- _53: double (nullable = true)
//  |-- _54: double (nullable = true)
//  |-- _55: double (nullable = true)
//  |-- _56: double (nullable = true)
//  |-- _57: double (nullable = true)
//  |-- _58: double (nullable = true)
//  |-- _59: double (nullable = true)
//  |-- _60: double (nullable = true)
//  |-- _61: double (nullable = true)
//  |-- _62: double (nullable = true)
//  |-- _63: double (nullable = true)
//  |-- _64: double (nullable = true)
//  |-- _65: double (nullable = true)
//  |-- _66: double (nullable = true)
//  |-- _67: double (nullable = true)
//  |-- _68: double (nullable = true)
//  |-- _69: double (nullable = true)
//  |-- _70: double (nullable = true)
//  |-- _71: double (nullable = true)
//  |-- _72: double (nullable = true)
//  |-- _73: double (nullable = true)
//  |-- _74: double (nullable = true)
//  |-- _75: double (nullable = true)
//  |-- _76: double (nullable = true)
//  |-- _77: double (nullable = true)
//  |-- _78: double (nullable = true)
//  |-- _79: double (nullable = true)
//  |-- _80: double (nullable = true)
//  |-- _81: double (nullable = true)
//  |-- _82: double (nullable = true)
//  |-- _83: double (nullable = true)
//  |-- _84: double (nullable = true)
//  |-- _85: double (nullable = true)
//  |-- _86: double (nullable = true)
//  |-- _87: double (nullable = true)
//  |-- _88: double (nullable = true)
//  |-- _89: double (nullable = true)
//  |-- _90: double (nullable = true)
//  |-- _91: double (nullable = true)
//  |-- _92: double (nullable = true)
//  |-- _93: double (nullable = true)
//  |-- _94: double (nullable = true)
//  |-- _95: double (nullable = true)
//  |-- _96: double (nullable = true)
//  |-- _97: double (nullable = true)
//  |-- _98: double (nullable = true)
//  |-- _99: double (nullable = true)
//  |-- _100: double (nullable = true)
//  |-- _101: double (nullable = true)
//  |-- _102: double (nullable = true)
//  |-- _103: double (nullable = true)
//  |-- _104: double (nullable = true)
//  |-- _105: double (nullable = true)
//  |-- _106: double (nullable = true)
//  |-- _107: double (nullable = true)
//  |-- _108: double (nullable = true)
//  |-- _109: double (nullable = true)
//  |-- _110: double (nullable = true)
//  |-- _111: double (nullable = true)
//  |-- _112: double (nullable = true)
//  |-- _113: double (nullable = true)
//  |-- _114: double (nullable = true)
//  |-- _115: double (nullable = true)
//  |-- _116: double (nullable = true)
//  |-- _117: double (nullable = true)
//  |-- _118: double (nullable = true)
//  |-- _119: double (nullable = true)
//  |-- _120: double (nullable = true)
//  |-- _121: double (nullable = true)
//  |-- _122: double (nullable = true)
//  |-- _123: double (nullable = true)
//  |-- _124: double (nullable = true)
//  |-- _125: double (nullable = true)
//  |-- _126: double (nullable = true)
//  |-- _127: double (nullable = true)
//  |-- _128: double (nullable = true)
//  |-- _129: double (nullable = true)
//  |-- _130: double (nullable = true)
//  |-- _131: double (nullable = true)
//  |-- _132: double (nullable = true)
//  |-- _133: double (nullable = true)
//  |-- _134: double (nullable = true)
//  |-- _135: double (nullable = true)
//  |-- _136: double (nullable = true)
//  |-- _137: double (nullable = true)
//  |-- _138: double (nullable = true)
//  |-- _139: double (nullable = true)
//  |-- _140: double (nullable = true)
//  |-- _141: double (nullable = true)
//  |-- _142: double (nullable = true)
//  |-- _143: double (nullable = true)
//  |-- _144: double (nullable = true)
//  |-- _145: double (nullable = true)
//  |-- _146: double (nullable = true)
//  |-- _147: double (nullable = true)
//  |-- _148: double (nullable = true)
//  |-- _149: double (nullable = true)
//  |-- _150: double (nullable = true)
//  |-- _151: double (nullable = true)
//  |-- _152: double (nullable = true)
//  |-- _153: double (nullable = true)
//  |-- _154: double (nullable = true)
//  |-- _155: double (nullable = true)
//  |-- _156: double (nullable = true)
//  |-- _157: double (nullable = true)
//  |-- _158: double (nullable = true)
//  |-- _159: double (nullable = true)
//  |-- _160: double (nullable = true)
//  |-- _161: double (nullable = true)
//  |-- _162: double (nullable = true)
//  |-- _163: double (nullable = true)
//  |-- _164: double (nullable = true)
//  |-- _165: double (nullable = true)
//  |-- _166: double (nullable = true)
//  |-- _167: double (nullable = true)
//  |-- _168: double (nullable = true)
//  |-- _169: double (nullable = true)
//  |-- _170: double (nullable = true)
//  |-- _171: double (nullable = true)
//  |-- _172: double (nullable = true)
//  |-- _173: double (nullable = true)
//  |-- _174: double (nullable = true)
//  |-- _175: double (nullable = true)
//  |-- _176: double (nullable = true)
//  |-- _177: double (nullable = true)
//  |-- _178: double (nullable = true)
//  |-- _179: double (nullable = true)
//  |-- _180: double (nullable = true)
//  |-- _181: double (nullable = true)
//  |-- _182: double (nullable = true)
//  |-- _183: double (nullable = true)
//  |-- _184: double (nullable = true)
//  |-- _185: double (nullable = true)
//  |-- _186: double (nullable = true)
//  |-- _187: double (nullable = true)
//  |-- _188: double (nullable = true)
//  |-- _189: double (nullable = true)
//  |-- _190: double (nullable = true)
//  |-- _191: double (nullable = true)
//  |-- _192: double (nullable = true)
//  |-- _193: double (nullable = true)
//  |-- _194: double (nullable = true)
//  |-- _195: double (nullable = true)
//  |-- _196: double (nullable = true)
//  |-- _197: double (nullable = true)
//  |-- _198: double (nullable = true)
//  |-- _199: double (nullable = true)
//  |-- _200: double (nullable = true)
//  |-- _201: double (nullable = true)
//  |-- _202: double (nullable = true)
//  |-- _203: double (nullable = true)
//  |-- _204: double (nullable = true)
//  |-- _205: double (nullable = true)
//  |-- _206: double (nullable = true)
//  |-- _207: double (nullable = true)
//  |-- _208: double (nullable = true)
//  |-- _209: double (nullable = true)
//  |-- _210: double (nullable = true)
//  |-- _211: double (nullable = true)
//  |-- _212: double (nullable = true)
//  |-- _213: double (nullable = true)
//  |-- _214: double (nullable = true)
//  |-- _215: double (nullable = true)
//  |-- _216: double (nullable = true)
//  |-- _217: double (nullable = true)
//  |-- _218: double (nullable = true)
//  |-- _219: double (nullable = true)
//  |-- _220: double (nullable = true)
//  |-- _221: double (nullable = true)
//  |-- _222: double (nullable = true)
//  |-- _223: double (nullable = true)
//  |-- _224: double (nullable = true)
//  |-- _225: double (nullable = true)
//  |-- _226: double (nullable = true)
//  |-- _227: double (nullable = true)
//  |-- _228: double (nullable = true)
//  |-- _229: double (nullable = true)
//  |-- _230: double (nullable = true)
//  |-- _231: double (nullable = true)
//  |-- _232: double (nullable = true)
//  |-- _233: double (nullable = true)
//  |-- _234: double (nullable = true)
//  |-- _235: double (nullable = true)
//  |-- _236: double (nullable = true)
//  |-- _237: double (nullable = true)
//  |-- _238: double (nullable = true)
//  |-- _239: double (nullable = true)
//  |-- _240: double (nullable = true)
//  |-- _241: double (nullable = true)
//  |-- _242: double (nullable = true)
//  |-- _243: double (nullable = true)
//  |-- _244: double (nullable = true)
//  |-- _245: double (nullable = true)
//  |-- _246: double (nullable = true)
//  |-- _247: double (nullable = true)
//  |-- _248: double (nullable = true)
//  |-- _249: double (nullable = true)
//  |-- _250: double (nullable = true)
//  |-- _251: double (nullable = true)
//  |-- _252: double (nullable = true)
//  |-- _253: double (nullable = true)
//  |-- _254: double (nullable = true)
//  |-- _255: double (nullable = true)
//  |-- _256: double (nullable = true)
//  |-- _257: double (nullable = true)
//  |-- _258: double (nullable = true)
//  |-- _259: double (nullable = true)
//  |-- _260: double (nullable = true)
//  |-- _261: double (nullable = true)
//  |-- _262: double (nullable = true)
//  |-- _263: double (nullable = true)
//  |-- _264: double (nullable = true)
//  |-- _265: double (nullable = true)
//  |-- _266: double (nullable = true)
//  |-- _267: double (nullable = true)
//  |-- _268: double (nullable = true)
//  |-- _269: double (nullable = true)
//  |-- _270: double (nullable = true)
//  |-- _271: double (nullable = true)
//  |-- _272: double (nullable = true)
//  |-- _273: double (nullable = true)
//  |-- _274: double (nullable = true)
//  |-- _275: double (nullable = true)
//  |-- _276: double (nullable = true)
//  |-- _277: double (nullable = true)
//  |-- _278: double (nullable = true)
//  |-- _279: double (nullable = true)
//  |-- _280: double (nullable = true)
//  |-- _281: double (nullable = true)
//  |-- _282: double (nullable = true)
//  |-- _283: double (nullable = true)
//  |-- _284: double (nullable = true)
//  |-- _285: double (nullable = true)
//  |-- _286: double (nullable = true)
//  |-- _287: double (nullable = true)
//  |-- _288: double (nullable = true)
//  |-- _289: double (nullable = true)
//  |-- _290: double (nullable = true)
//  |-- _291: double (nullable = true)
//  |-- _292: double (nullable = true)
//  |-- _293: double (nullable = true)
//  |-- _294: double (nullable = true)
//  |-- _295: double (nullable = true)
//  |-- _296: double (nullable = true)
//  |-- _297: double (nullable = true)
//  |-- _298: double (nullable = true)
//  |-- _299: double (nullable = true)
//  |-- _300: double (nullable = true)
//  |-- _301: double (nullable = true)
//  |-- _302: double (nullable = true)
//  |-- _303: double (nullable = true)
//  |-- _304: double (nullable = true)
//  |-- _305: double (nullable = true)
//  |-- _306: double (nullable = true)
//  |-- _307: double (nullable = true)
//  |-- _308: double (nullable = true)
//  |-- _309: double (nullable = true)
//  |-- _310: double (nullable = true)
//  |-- _311: double (nullable = true)
//  |-- _312: double (nullable = true)
//  |-- _313: double (nullable = true)
//  |-- _314: double (nullable = true)
//  |-- _315: double (nullable = true)
//  |-- _316: double (nullable = true)
//  |-- _317: double (nullable = true)
//  |-- _318: double (nullable = true)
//  |-- _319: double (nullable = true)
//  |-- _320: double (nullable = true)
//  |-- _321: double (nullable = true)
//  |-- _322: double (nullable = true)
//  |-- _323: double (nullable = true)
//  |-- _324: double (nullable = true)
//  |-- _325: double (nullable = true)
//  |-- _326: double (nullable = true)
//  |-- _327: double (nullable = true)
//  |-- _328: double (nullable = true)
//  |-- _329: double (nullable = true)
//  |-- _330: double (nullable = true)
//  |-- _331: double (nullable = true)
//  |-- _332: double (nullable = true)
//  |-- _333: double (nullable = true)
//  |-- _334: double (nullable = true)
//  |-- _335: double (nullable = true)
//  |-- _336: double (nullable = true)
//  |-- _337: double (nullable = true)
//  |-- _338: double (nullable = true)
//  |-- _339: double (nullable = true)
//  |-- _340: double (nullable = true)
//  |-- _341: double (nullable = true)
//  |-- _342: double (nullable = true)
//  |-- _343: double (nullable = true)
//  |-- _344: double (nullable = true)
//  |-- _345: double (nullable = true)
//  |-- _346: double (nullable = true)
//  |-- _347: double (nullable = true)
//  |-- _348: double (nullable = true)
//  |-- _349: double (nullable = true)
//  |-- _350: double (nullable = true)
//  |-- _351: double (nullable = true)
//  |-- _352: double (nullable = true)
//  |-- _353: double (nullable = true)
//  |-- _354: double (nullable = true)
//  |-- _355: double (nullable = true)
//  |-- _356: double (nullable = true)
//  |-- _357: double (nullable = true)
//  |-- _358: double (nullable = true)
//  |-- _359: double (nullable = true)
//  |-- _360: double (nullable = true)
//  |-- _361: double (nullable = true)
//  |-- _362: double (nullable = true)
//  |-- _363: double (nullable = true)
//  |-- _364: double (nullable = true)
//  |-- _365: double (nullable = true)
//  |-- target: integer (nullable = true)

// %%
print(df_all.columns.toSeq)
// Out:
// WrappedArray(_1, _2, _3, _4, _5, _6, _7, _8, _9, _10, _11, _12, _13, _14, _15, _16, _17, _18, _19, _20, _21, _22, _23, _24, _25, _26, _27, _28, _29, _30, _31, _32, _33, _34, _35, _36, _37, _38, _39, _40, _41, _42, _43, _44, _45, _46, _47, _48, _49, _50, _51, _52, _53, _54, _55, _56, _57, _58, _59, _60, _61, _62, _63, _64, _65, _66, _67, _68, _69, _70, _71, _72, _73, _74, _75, _76, _77, _78, _79, _80, _81, _82, _83, _84, _85, _86, _87, _88, _89, _90, _91, _92, _93, _94, _95, _96, _97, _98, _99, _100, _101, _102, _103, _104, _105, _106, _107, _108, _109, _110, _111, _112, _113, _114, _115, _116, _117, _118, _119, _120, _121, _122, _123, _124, _125, _126, _127, _128, _129, _130, _131, _132, _133, _134, _135, _136, _137, _138, _139, _140, _141, _142, _143, _144, _145, _146, _147, _148, _149, _150, _151, _152, _153, _154, _155, _156, _157, _158, _159, _160, _161, _162, _163, _164, _165, _166, _167, _168, _169, _170, _171, _172, _173, _174, _175, _176, _177, _178, _179, _180, _181, _182, _183, _184, _185, _186, _187, _188, _189, _190, _191, _192, _193, _194, _195, _196, _197, _198, _199, _200, _201, _202, _203, _204, _205, _206, _207, _208, _209, _210, _211, _212, _213, _214, _215, _216, _217, _218, _219, _220, _221, _222, _223, _224, _225, _226, _227, _228, _229, _230, _231, _232, _233, _234, _235, _236, _237, _238, _239, _240, _241, _242, _243, _244, _245, _246, _247, _248, _249, _250, _251, _252, _253, _254, _255, _256, _257, _258, _259, _260, _261, _262, _263, _264, _265, _266, _267, _268, _269, _270, _271, _272, _273, _274, _275, _276, _277, _278, _279, _280, _281, _282, _283, _284, _285, _286, _287, _288, _289, _290, _291, _292, _293, _294, _295, _296, _297, _298, _299, _300, _301, _302, _303, _304, _305, _306, _307, _308, _309, _310, _311, _312, _313, _314, _315, _316, _317, _318, _319, _320, _321, _322, _323, _324, _325, _326, _327, _328, _329, _330, _331, _332, _333, _334, _335, _336, _337, _338, _339, _340, _341, _342, _343, _344, _345, _346, _347, _348, _349, _350, _351, _352, _353, _354, _355, _356, _357, _358, _359, _360, _361, _362, _363, _364, _365, target)

// %%
print(df_all.columns.slice(0,365).map(a => a.toString ).toSeq)
// Out:
// WrappedArray(_1, _2, _3, _4, _5, _6, _7, _8, _9, _10, _11, _12, _13, _14, _15, _16, _17, _18, _19, _20, _21, _22, _23, _24, _25, _26, _27, _28, _29, _30, _31, _32, _33, _34, _35, _36, _37, _38, _39, _40, _41, _42, _43, _44, _45, _46, _47, _48, _49, _50, _51, _52, _53, _54, _55, _56, _57, _58, _59, _60, _61, _62, _63, _64, _65, _66, _67, _68, _69, _70, _71, _72, _73, _74, _75, _76, _77, _78, _79, _80, _81, _82, _83, _84, _85, _86, _87, _88, _89, _90, _91, _92, _93, _94, _95, _96, _97, _98, _99, _100, _101, _102, _103, _104, _105, _106, _107, _108, _109, _110, _111, _112, _113, _114, _115, _116, _117, _118, _119, _120, _121, _122, _123, _124, _125, _126, _127, _128, _129, _130, _131, _132, _133, _134, _135, _136, _137, _138, _139, _140, _141, _142, _143, _144, _145, _146, _147, _148, _149, _150, _151, _152, _153, _154, _155, _156, _157, _158, _159, _160, _161, _162, _163, _164, _165, _166, _167, _168, _169, _170, _171, _172, _173, _174, _175, _176, _177, _178, _179, _180, _181, _182, _183, _184, _185, _186, _187, _188, _189, _190, _191, _192, _193, _194, _195, _196, _197, _198, _199, _200, _201, _202, _203, _204, _205, _206, _207, _208, _209, _210, _211, _212, _213, _214, _215, _216, _217, _218, _219, _220, _221, _222, _223, _224, _225, _226, _227, _228, _229, _230, _231, _232, _233, _234, _235, _236, _237, _238, _239, _240, _241, _242, _243, _244, _245, _246, _247, _248, _249, _250, _251, _252, _253, _254, _255, _256, _257, _258, _259, _260, _261, _262, _263, _264, _265, _266, _267, _268, _269, _270, _271, _272, _273, _274, _275, _276, _277, _278, _279, _280, _281, _282, _283, _284, _285, _286, _287, _288, _289, _290, _291, _292, _293, _294, _295, _296, _297, _298, _299, _300, _301, _302, _303, _304, _305, _306, _307, _308, _309, _310, _311, _312, _313, _314, _315, _316, _317, _318, _319, _320, _321, _322, _323, _324, _325, _326, _327, _328, _329, _330, _331, _332, _333, _334, _335, _336, _337, _338, _339, _340, _341, _342, _343, _344, _345, _346, _347, _348, _349, _350, _351, _352, _353, _354, _355, _356, _357, _358, _359, _360, _361, _362, _363, _364, _365)

// %%
import org.apache.spark.ml.feature.{MinMaxScaler,StandardScaler,Normalizer, MaxAbsScaler}
import org.apache.spark.ml.{Pipeline}
import org.apache.spark.ml.feature.VectorAssembler

val assembler = new VectorAssembler().setInputCols(df_all.columns.slice(0,365).map(a => a.toString).toArray).setOutputCol("features")

val df_all_features = assembler.transform(df_all)

// scaler instance with the min(-1) and max(1) 
val mms = new MinMaxScaler().
    setInputCol("features").
    setOutputCol("mms").
    setMax(1).
    setMin(-1)

// scaler instance with the min(0) and max(1) 
val mms01 = new MinMaxScaler().
    setInputCol("features").
    setOutputCol("mms").
    setMax(1).
    setMin(0)

val stds = new StandardScaler().
    setInputCol("features").
    setOutputCol("stds")

val maxabsscaler = new MaxAbsScaler().
    setInputCol("features").
    setOutputCol("maxabsscaler")

val mms_tr = mms.setInputCol("features").setOutputCol("mms")
val mms01_tr = mms01.setInputCol("features").setOutputCol("mms01")
val mms_abs_tr = maxabsscaler.setInputCol("features").setOutputCol("maxabsscaler")
val stds_tr = stds.setInputCol("features").setOutputCol("stds")

val trainingFeaturesPipeline = (new Pipeline()
  .setStages(Array(mms_tr,mms01_tr,mms_abs_tr,stds_tr)))
val trainingFeaturesDF = trainingFeaturesPipeline.fit(df_all_features).transform(df_all_features)
// Out:
// import org.apache.spark.ml.feature.{MinMaxScaler, StandardScaler, Normalizer, MaxAbsScaler}
// import org.apache.spark.ml.Pipeline
// import org.apache.spark.ml.feature.VectorAssembler
// assembler: org.apache.spark.ml.feature.VectorAssembler = vecAssembler_cb7f72de861a
// df_all_features: org.apache.spark.sql.DataFrame = [_1: double, _2: double ... 365 more fields]
// mms: org.apache.spark.ml.feature.MinMaxScaler = minMaxScal_d291fd56bde6
// mms01: org.apache.spark.ml.feature.MinMaxScaler = minMaxScal_b07cdcc82df9
// stds: org.apache.spark.ml.feature.StandardScaler = stdScal_744f6523d451
// maxabsscaler: org.apache.spark.ml.feature.MaxAbsScaler = maxAbsScal_2007c2bb5be0
// mms_tr: mms.type = minMaxScal_d291fd56bde6
// mms01_tr: mms01.type = minMaxScal_b07cdcc82df9
// mms_abs_tr: maxabsscaler.type = maxAbsScal_2007c2bb5be0
// stds_tr: stds.type = stdScal_744f6523d451
// trainingFeaturesPipeline: org.apache.spark.ml.Pipeline = pipeline_c716360627e9
// trainingFeaturesDF: org.apache.spark.sql.DataFrame = [_1: double, _2: double ... 369 more fields]

// %%
trainingFeaturesDF.printSchema
// Out:
// root
//  |-- _1: double (nullable = true)
//  |-- _2: double (nullable = true)
//  |-- _3: double (nullable = true)
//  |-- _4: double (nullable = true)
//  |-- _5: double (nullable = true)
//  |-- _6: double (nullable = true)
//  |-- _7: double (nullable = true)
//  |-- _8: double (nullable = true)
//  |-- _9: double (nullable = true)
//  |-- _10: double (nullable = true)
//  |-- _11: double (nullable = true)
//  |-- _12: double (nullable = true)
//  |-- _13: double (nullable = true)
//  |-- _14: double (nullable = true)
//  |-- _15: double (nullable = true)
//  |-- _16: double (nullable = true)
//  |-- _17: double (nullable = true)
//  |-- _18: double (nullable = true)
//  |-- _19: double (nullable = true)
//  |-- _20: double (nullable = true)
//  |-- _21: double (nullable = true)
//  |-- _22: double (nullable = true)
//  |-- _23: double (nullable = true)
//  |-- _24: double (nullable = true)
//  |-- _25: double (nullable = true)
//  |-- _26: double (nullable = true)
//  |-- _27: double (nullable = true)
//  |-- _28: double (nullable = true)
//  |-- _29: double (nullable = true)
//  |-- _30: double (nullable = true)
//  |-- _31: double (nullable = true)
//  |-- _32: double (nullable = true)
//  |-- _33: double (nullable = true)
//  |-- _34: double (nullable = true)
//  |-- _35: double (nullable = true)
//  |-- _36: double (nullable = true)
//  |-- _37: double (nullable = true)
//  |-- _38: double (nullable = true)
//  |-- _39: double (nullable = true)
//  |-- _40: double (nullable = true)
//  |-- _41: double (nullable = true)
//  |-- _42: double (nullable = true)
//  |-- _43: double (nullable = true)
//  |-- _44: double (nullable = true)
//  |-- _45: double (nullable = true)
//  |-- _46: double (nullable = true)
//  |-- _47: double (nullable = true)
//  |-- _48: double (nullable = true)
//  |-- _49: double (nullable = true)
//  |-- _50: double (nullable = true)
//  |-- _51: double (nullable = true)
//  |-- _52: double (nullable = true)
//  |-- _53: double (nullable = true)
//  |-- _54: double (nullable = true)
//  |-- _55: double (nullable = true)
//  |-- _56: double (nullable = true)
//  |-- _57: double (nullable = true)
//  |-- _58: double (nullable = true)
//  |-- _59: double (nullable = true)
//  |-- _60: double (nullable = true)
//  |-- _61: double (nullable = true)
//  |-- _62: double (nullable = true)
//  |-- _63: double (nullable = true)
//  |-- _64: double (nullable = true)
//  |-- _65: double (nullable = true)
//  |-- _66: double (nullable = true)
//  |-- _67: double (nullable = true)
//  |-- _68: double (nullable = true)
//  |-- _69: double (nullable = true)
//  |-- _70: double (nullable = true)
//  |-- _71: double (nullable = true)
//  |-- _72: double (nullable = true)
//  |-- _73: double (nullable = true)
//  |-- _74: double (nullable = true)
//  |-- _75: double (nullable = true)
//  |-- _76: double (nullable = true)
//  |-- _77: double (nullable = true)
//  |-- _78: double (nullable = true)
//  |-- _79: double (nullable = true)
//  |-- _80: double (nullable = true)
//  |-- _81: double (nullable = true)
//  |-- _82: double (nullable = true)
//  |-- _83: double (nullable = true)
//  |-- _84: double (nullable = true)
//  |-- _85: double (nullable = true)
//  |-- _86: double (nullable = true)
//  |-- _87: double (nullable = true)
//  |-- _88: double (nullable = true)
//  |-- _89: double (nullable = true)
//  |-- _90: double (nullable = true)
//  |-- _91: double (nullable = true)
//  |-- _92: double (nullable = true)
//  |-- _93: double (nullable = true)
//  |-- _94: double (nullable = true)
//  |-- _95: double (nullable = true)
//  |-- _96: double (nullable = true)
//  |-- _97: double (nullable = true)
//  |-- _98: double (nullable = true)
//  |-- _99: double (nullable = true)
//  |-- _100: double (nullable = true)
//  |-- _101: double (nullable = true)
//  |-- _102: double (nullable = true)
//  |-- _103: double (nullable = true)
//  |-- _104: double (nullable = true)
//  |-- _105: double (nullable = true)
//  |-- _106: double (nullable = true)
//  |-- _107: double (nullable = true)
//  |-- _108: double (nullable = true)
//  |-- _109: double (nullable = true)
//  |-- _110: double (nullable = true)
//  |-- _111: double (nullable = true)
//  |-- _112: double (nullable = true)
//  |-- _113: double (nullable = true)
//  |-- _114: double (nullable = true)
//  |-- _115: double (nullable = true)
//  |-- _116: double (nullable = true)
//  |-- _117: double (nullable = true)
//  |-- _118: double (nullable = true)
//  |-- _119: double (nullable = true)
//  |-- _120: double (nullable = true)
//  |-- _121: double (nullable = true)
//  |-- _122: double (nullable = true)
//  |-- _123: double (nullable = true)
//  |-- _124: double (nullable = true)
//  |-- _125: double (nullable = true)
//  |-- _126: double (nullable = true)
//  |-- _127: double (nullable = true)
//  |-- _128: double (nullable = true)
//  |-- _129: double (nullable = true)
//  |-- _130: double (nullable = true)
//  |-- _131: double (nullable = true)
//  |-- _132: double (nullable = true)
//  |-- _133: double (nullable = true)
//  |-- _134: double (nullable = true)
//  |-- _135: double (nullable = true)
//  |-- _136: double (nullable = true)
//  |-- _137: double (nullable = true)
//  |-- _138: double (nullable = true)
//  |-- _139: double (nullable = true)
//  |-- _140: double (nullable = true)
//  |-- _141: double (nullable = true)
//  |-- _142: double (nullable = true)
//  |-- _143: double (nullable = true)
//  |-- _144: double (nullable = true)
//  |-- _145: double (nullable = true)
//  |-- _146: double (nullable = true)
//  |-- _147: double (nullable = true)
//  |-- _148: double (nullable = true)
//  |-- _149: double (nullable = true)
//  |-- _150: double (nullable = true)
//  |-- _151: double (nullable = true)
//  |-- _152: double (nullable = true)
//  |-- _153: double (nullable = true)
//  |-- _154: double (nullable = true)
//  |-- _155: double (nullable = true)
//  |-- _156: double (nullable = true)
//  |-- _157: double (nullable = true)
//  |-- _158: double (nullable = true)
//  |-- _159: double (nullable = true)
//  |-- _160: double (nullable = true)
//  |-- _161: double (nullable = true)
//  |-- _162: double (nullable = true)
//  |-- _163: double (nullable = true)
//  |-- _164: double (nullable = true)
//  |-- _165: double (nullable = true)
//  |-- _166: double (nullable = true)
//  |-- _167: double (nullable = true)
//  |-- _168: double (nullable = true)
//  |-- _169: double (nullable = true)
//  |-- _170: double (nullable = true)
//  |-- _171: double (nullable = true)
//  |-- _172: double (nullable = true)
//  |-- _173: double (nullable = true)
//  |-- _174: double (nullable = true)
//  |-- _175: double (nullable = true)
//  |-- _176: double (nullable = true)
//  |-- _177: double (nullable = true)
//  |-- _178: double (nullable = true)
//  |-- _179: double (nullable = true)
//  |-- _180: double (nullable = true)
//  |-- _181: double (nullable = true)
//  |-- _182: double (nullable = true)
//  |-- _183: double (nullable = true)
//  |-- _184: double (nullable = true)
//  |-- _185: double (nullable = true)
//  |-- _186: double (nullable = true)
//  |-- _187: double (nullable = true)
//  |-- _188: double (nullable = true)
//  |-- _189: double (nullable = true)
//  |-- _190: double (nullable = true)
//  |-- _191: double (nullable = true)
//  |-- _192: double (nullable = true)
//  |-- _193: double (nullable = true)
//  |-- _194: double (nullable = true)
//  |-- _195: double (nullable = true)
//  |-- _196: double (nullable = true)
//  |-- _197: double (nullable = true)
//  |-- _198: double (nullable = true)
//  |-- _199: double (nullable = true)
//  |-- _200: double (nullable = true)
//  |-- _201: double (nullable = true)
//  |-- _202: double (nullable = true)
//  |-- _203: double (nullable = true)
//  |-- _204: double (nullable = true)
//  |-- _205: double (nullable = true)
//  |-- _206: double (nullable = true)
//  |-- _207: double (nullable = true)
//  |-- _208: double (nullable = true)
//  |-- _209: double (nullable = true)
//  |-- _210: double (nullable = true)
//  |-- _211: double (nullable = true)
//  |-- _212: double (nullable = true)
//  |-- _213: double (nullable = true)
//  |-- _214: double (nullable = true)
//  |-- _215: double (nullable = true)
//  |-- _216: double (nullable = true)
//  |-- _217: double (nullable = true)
//  |-- _218: double (nullable = true)
//  |-- _219: double (nullable = true)
//  |-- _220: double (nullable = true)
//  |-- _221: double (nullable = true)
//  |-- _222: double (nullable = true)
//  |-- _223: double (nullable = true)
//  |-- _224: double (nullable = true)
//  |-- _225: double (nullable = true)
//  |-- _226: double (nullable = true)
//  |-- _227: double (nullable = true)
//  |-- _228: double (nullable = true)
//  |-- _229: double (nullable = true)
//  |-- _230: double (nullable = true)
//  |-- _231: double (nullable = true)
//  |-- _232: double (nullable = true)
//  |-- _233: double (nullable = true)
//  |-- _234: double (nullable = true)
//  |-- _235: double (nullable = true)
//  |-- _236: double (nullable = true)
//  |-- _237: double (nullable = true)
//  |-- _238: double (nullable = true)
//  |-- _239: double (nullable = true)
//  |-- _240: double (nullable = true)
//  |-- _241: double (nullable = true)
//  |-- _242: double (nullable = true)
//  |-- _243: double (nullable = true)
//  |-- _244: double (nullable = true)
//  |-- _245: double (nullable = true)
//  |-- _246: double (nullable = true)
//  |-- _247: double (nullable = true)
//  |-- _248: double (nullable = true)
//  |-- _249: double (nullable = true)
//  |-- _250: double (nullable = true)
//  |-- _251: double (nullable = true)
//  |-- _252: double (nullable = true)
//  |-- _253: double (nullable = true)
//  |-- _254: double (nullable = true)
//  |-- _255: double (nullable = true)
//  |-- _256: double (nullable = true)
//  |-- _257: double (nullable = true)
//  |-- _258: double (nullable = true)
//  |-- _259: double (nullable = true)
//  |-- _260: double (nullable = true)
//  |-- _261: double (nullable = true)
//  |-- _262: double (nullable = true)
//  |-- _263: double (nullable = true)
//  |-- _264: double (nullable = true)
//  |-- _265: double (nullable = true)
//  |-- _266: double (nullable = true)
//  |-- _267: double (nullable = true)
//  |-- _268: double (nullable = true)
//  |-- _269: double (nullable = true)
//  |-- _270: double (nullable = true)
//  |-- _271: double (nullable = true)
//  |-- _272: double (nullable = true)
//  |-- _273: double (nullable = true)
//  |-- _274: double (nullable = true)
//  |-- _275: double (nullable = true)
//  |-- _276: double (nullable = true)
//  |-- _277: double (nullable = true)
//  |-- _278: double (nullable = true)
//  |-- _279: double (nullable = true)
//  |-- _280: double (nullable = true)
//  |-- _281: double (nullable = true)
//  |-- _282: double (nullable = true)
//  |-- _283: double (nullable = true)
//  |-- _284: double (nullable = true)
//  |-- _285: double (nullable = true)
//  |-- _286: double (nullable = true)
//  |-- _287: double (nullable = true)
//  |-- _288: double (nullable = true)
//  |-- _289: double (nullable = true)
//  |-- _290: double (nullable = true)
//  |-- _291: double (nullable = true)
//  |-- _292: double (nullable = true)
//  |-- _293: double (nullable = true)
//  |-- _294: double (nullable = true)
//  |-- _295: double (nullable = true)
//  |-- _296: double (nullable = true)
//  |-- _297: double (nullable = true)
//  |-- _298: double (nullable = true)
//  |-- _299: double (nullable = true)
//  |-- _300: double (nullable = true)
//  |-- _301: double (nullable = true)
//  |-- _302: double (nullable = true)
//  |-- _303: double (nullable = true)
//  |-- _304: double (nullable = true)
//  |-- _305: double (nullable = true)
//  |-- _306: double (nullable = true)
//  |-- _307: double (nullable = true)
//  |-- _308: double (nullable = true)
//  |-- _309: double (nullable = true)
//  |-- _310: double (nullable = true)
//  |-- _311: double (nullable = true)
//  |-- _312: double (nullable = true)
//  |-- _313: double (nullable = true)
//  |-- _314: double (nullable = true)
//  |-- _315: double (nullable = true)
//  |-- _316: double (nullable = true)
//  |-- _317: double (nullable = true)
//  |-- _318: double (nullable = true)
//  |-- _319: double (nullable = true)
//  |-- _320: double (nullable = true)
//  |-- _321: double (nullable = true)
//  |-- _322: double (nullable = true)
//  |-- _323: double (nullable = true)
//  |-- _324: double (nullable = true)
//  |-- _325: double (nullable = true)
//  |-- _326: double (nullable = true)
//  |-- _327: double (nullable = true)
//  |-- _328: double (nullable = true)
//  |-- _329: double (nullable = true)
//  |-- _330: double (nullable = true)
//  |-- _331: double (nullable = true)
//  |-- _332: double (nullable = true)
//  |-- _333: double (nullable = true)
//  |-- _334: double (nullable = true)
//  |-- _335: double (nullable = true)
//  |-- _336: double (nullable = true)
//  |-- _337: double (nullable = true)
//  |-- _338: double (nullable = true)
//  |-- _339: double (nullable = true)
//  |-- _340: double (nullable = true)
//  |-- _341: double (nullable = true)
//  |-- _342: double (nullable = true)
//  |-- _343: double (nullable = true)
//  |-- _344: double (nullable = true)
//  |-- _345: double (nullable = true)
//  |-- _346: double (nullable = true)
//  |-- _347: double (nullable = true)
//  |-- _348: double (nullable = true)
//  |-- _349: double (nullable = true)
//  |-- _350: double (nullable = true)
//  |-- _351: double (nullable = true)
//  |-- _352: double (nullable = true)
//  |-- _353: double (nullable = true)
//  |-- _354: double (nullable = true)
//  |-- _355: double (nullable = true)
//  |-- _356: double (nullable = true)
//  |-- _357: double (nullable = true)
//  |-- _358: double (nullable = true)
//  |-- _359: double (nullable = true)
//  |-- _360: double (nullable = true)
//  |-- _361: double (nullable = true)
//  |-- _362: double (nullable = true)
//  |-- _363: double (nullable = true)
//  |-- _364: double (nullable = true)
//  |-- _365: double (nullable = true)
//  |-- target: integer (nullable = true)
//  |-- features: vector (nullable = true)
//  |-- mms: vector (nullable = true)
//  |-- mms01: vector (nullable = true)
//  |-- maxabsscaler: vector (nullable = true)
//  |-- stds: vector (nullable = true)

// %%
import org.apache.spark.ml.linalg.DenseVector
val toArr: Any => Array[Double] = _.asInstanceOf[DenseVector].toArray
val toArrUdf = udf(toArr)
val final_df_all = trainingFeaturesDF.select($"target",$"features",$"mms",$"mms01",$"maxabsscaler",$"stds").  
             withColumn("features",toArrUdf($"features").cast(ArrayType(FloatType))).
             withColumn("mms",toArrUdf($"mms").cast(ArrayType(FloatType))).
             withColumn("mms01",toArrUdf($"mms01").cast(ArrayType(FloatType))).
             withColumn("maxabsscaler",toArrUdf($"maxabsscaler").cast(ArrayType(FloatType))).
             withColumn("stds",toArrUdf($"stds").cast(ArrayType(FloatType)))
// Out:
// import org.apache.spark.ml.linalg.DenseVector
// toArr: Any => Array[Double] = <function1>
// toArrUdf: org.apache.spark.sql.expressions.UserDefinedFunction = UserDefinedFunction(<function1>,ArrayType(DoubleType,false),None)
// final_df_all: org.apache.spark.sql.DataFrame = [target: int, features: array<float> ... 4 more fields]

// %%
val van = final_df_all.where($"target"===1)
val ben = final_df_all.where($"target"===0)
// Out:
// van: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [target: int, features: array<float> ... 4 more fields]
// ben: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [target: int, features: array<float> ... 4 more fields]

// %%
// Now that the data has been prepared, let's split the dataset into a training and test dataframe
val Array(benTrainDF, benEvalDF) = final_df_all.randomSplit(Array(0.8, 0.02),seed = 12345)
// Out:
// benTrainDF: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [target: int, features: array<float> ... 4 more fields]
// benEvalDF: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [target: int, features: array<float> ... 4 more fields]

// %%
benTrainDF.count()
// Out:
// res47: Long = 497739

// %%
benEvalDF.count()
// Out:
// res48: Long = 12263

// %%
val EvalDF = benEvalDF.union(van)
// Out:
// EvalDF: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [target: int, features: array<float> ... 4 more fields]

// %%
EvalDF.where($"target"===1).count()
// Out:
// res49: Long = 10232

// %%
EvalDF.where($"target"===0).count()
// Out:
// res50: Long = 12124

// %%
benTrainDF.write.format("tfrecords").mode("overwrite").save("hdfs:///Projects/aml_dev/aml_dev_Training_Datasets/train.tfrecord")
EvalDF.orderBy(rand()).write.format("tfrecords").mode("overwrite").save("hdfs:///Projects/aml_dev/aml_dev_Training_Datasets/eval.tfrecord")

// %%
EvalDF.show()
// Out:
// +------+--------------------+--------------------+--------------------+--------------------+--------------------+
// |target|            features|                 mms|               mms01|        maxabsscaler|                stds|
// +------+--------------------+--------------------+--------------------+--------------------+--------------------+
// |     0|[-3.776158, -3.92...|[-0.4374575, -0.0...|[0.28127125, 0.46...|[-0.10338093, -0....|[-3.7483687, -2.7...|
// |     0|[-2.9972315, -1.7...|[-0.40967596, -0....|[0.29516202, 0.49...|[-0.082056046, -0...|[-2.9751744, -1.2...|
// |     0|[-2.8602972, -3.4...|[-0.40479198, -0....|[0.297604, 0.4753...|[-0.07830715, -0....|[-2.8392477, -2.4...|
// |     0|[-2.5746126, -0.6...|[-0.39460263, 0.0...|[0.30269867, 0.51...|[-0.07048589, -0....|[-2.5556657, -0.4...|
// |     0|[-2.317746, -2.36...|[-0.38544112, -0....|[0.30727944, 0.48...|[-0.06345358, -0....|[-2.3006892, -1.6...|
// |     0|[-2.310101, -0.69...|[-0.38516846, 0.0...|[0.30741578, 0.51...|[-0.06324428, -0....|[-2.2931006, -0.4...|
// |     0|[-2.3079321, -1.2...|[-0.3850911, 0.00...|[0.30745447, 0.50...|[-0.0631849, -0.0...|[-2.2909477, -0.8...|
// |     0|[-2.274802, -2.90...|[-0.38390946, -0....|[0.30804527, 0.48...|[-0.062277887, -0...|[-2.2580612, -2.0...|
// |     0|[-2.2275407, -2.4...|[-0.3822238, -0.0...|[0.30888808, 0.48...|[-0.060984, -0.05...|[-2.2111478, -1.7...|
// |     0|[-2.22049, -0.354...|[-0.38197234, 0.0...|[0.3090138, 0.515...|[-0.06079097, -0....|[-2.204149, -0.24...|
// |     0|[-2.2078302, -1.5...|[-0.3815208, -6.2...|[0.3092396, 0.499...|[-0.060444385, -0...|[-2.1915824, -1.1...|
// |     0|[-2.199626, -0.72...|[-0.3812282, 0.02...|[0.3093859, 0.510...|[-0.06021977, -0....|[-2.1834383, -0.5...|
// |     0|[-2.1712313, -2.5...|[-0.38021547, -0....|[0.30989227, 0.48...|[-0.059442405, -0...|[-2.155253, -1.79...|
// |     0|[-2.1685028, -3.2...|[-0.38011816, -0....|[0.30994093, 0.47...|[-0.05936771, -0....|[-2.1525445, -2.2...|
// |     0|[-2.1380002, -1.6...|[-0.37903023, -0....|[0.3104849, 0.498...|[-0.058532625, -0...|[-2.1222663, -1.1...|
// |     0|[-2.0898433, -1.0...|[-0.37731263, 0.0...|[0.31134367, 0.50...|[-0.05721422, -0....|[-2.0744636, -0.7...|
// |     0|[-2.0693152, -0.7...|[-0.37658048, 0.0...|[0.31170976, 0.51...|[-0.056652214, -0...|[-2.0540867, -0.5...|
// |     0|[-2.0441742, -2.9...|[-0.37568378, -0....|[0.3121581, 0.482...|[-0.055963926, -0...|[-2.0291307, -2.0...|
// |     0|[-2.0161614, -0.1...|[-0.37468466, 0.0...|[0.31265765, 0.51...|[-0.055197015, -0...|[-2.0013242, -0.0...|
// |     0|[-1.9985482, -2.3...|[-0.37405646, -0....|[0.31297177, 0.48...|[-0.05471481, -0....|[-1.9838405, -1.6...|
// +------+--------------------+--------------------+--------------------+--------------------+--------------------+
// only showing top 20 rows
